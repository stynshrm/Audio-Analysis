# %%
#~/Documents/DSRProject/smaple-gitCodes/fooling-02/DeepAudioClassification-test

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import librosa
import librosa.display
import IPython.display as ipd

# %%
#Data is from anser%20brachyrhynchus37.mp3
data37, sampling_rate37 = librosa.load('./Data/MIR/genres/anserbra/anserbra37.mp3', mono=False)

plt.figure(figsize=(12, 4))
librosa.display.waveplot(data37, sr=sampling_rate37)

# %%
ipd.Audio('./Data/MIR/genres/anserbra/anserbra37.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Data is from anser%20brachyrhynchus23.mp3
data23, sampling_rate23 = librosa.load('./Data/MIR/genres/anserbra/anserbra23.mp3')
plt.figure(figsize=(12, 4))
librosa.display.waveplot(data23, sr=sampling_rate23)

# %%
ipd.Audio('./Data/MIR/genres/anserbra/anserbra23.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Data is from anser%20brachyrhynchus10.mp3
data10, sampling_rate10 = librosa.load('./Data/MIR/genres/anserbra/anserbra10.mp3')
plt.figure(figsize=(12, 4))
librosa.display.waveplot(data10, sr=sampling_rate10)

# %%
ipd.Audio('./Data/MIR/genres/anserbra/anserbra10.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
